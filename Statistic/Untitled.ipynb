# %%
from numpy.random import seed,randn
from matplotlib import pyplot
seed(1)
data=5*randn(1000)+50
pyplot.hist(data)#paramater bins: it define the number of equal-width bins in the range
pyplot.show()
