# %%
import pandas as pd
import numpy as np
#There are 2 core object in Pandas: DataFrame and Series

# %%
pd.DataFrame({'Yes':[50,21],'No':[100,250]})
# Out:
#    Yes   No
# 0   50  100
# 1   21  250

# %%
pd.DataFrame({'Data Science':['Data Scientist','Data Engineer','Data Research'],
             'AI':['Computer Vision','Machine Learning','Business Intelligent']})
# Out:
#      Data Science                    AI
# 0  Data Scientist       Computer Vision
# 1   Data Engineer      Machine Learning
# 2   Data Research  Business Intelligent

# %%
pd.Series([30,40,50],index=['2015 Sales','2016 Sales','2017 Sales'],name="T-shirt")
# Out:
# 2015 Sales    30
# 2016 Sales    40
# 2017 Sales    50
# Name: T-shirt, dtype: int64

# %%
sonar=pd.read_csv("/home/daominhkhanh/Documents/MachineLearning/Library/Pandas/sonar_csv.csv")

# %%
sonar.head()
# Out:
#    attribute_1  attribute_2  attribute_3  attribute_4  attribute_5  \
# 0       0.0200       0.0371       0.0428       0.0207       0.0954
# 1       0.0453       0.0523       0.0843       0.0689       0.1183
# 2       0.0262       0.0582       0.1099       0.1083       0.0974
# 3       0.0100       0.0171       0.0623       0.0205       0.0205
# 4       0.0762       0.0666       0.0481       0.0394       0.0590
#
#    attribute_6  attribute_7  attribute_8  attribute_9  attribute_10  ...  \
# 0       0.0986       0.1539       0.1601       0.3109        0.2111  ...
# 1       0.2583       0.2156       0.3481       0.3337        0.2872  ...
# 2       0.2280       0.2431       0.3771       0.5598        0.6194  ...
# 3       0.0368       0.1098       0.1276       0.0598        0.1264  ...
# 4       0.0649       0.1209       0.2467       0.3564        0.4459  ...
#
#    attribute_52  attribute_53  attribute_54  attribute_55  attribute_56  \
# ...

# %%
sonar.shape
# Out:
# (208, 61)

# %%
sonar
# Out:
#      attribute_1  attribute_2  attribute_3  attribute_4  attribute_5  \
# 0         0.0200       0.0371       0.0428       0.0207       0.0954
# 1         0.0453       0.0523       0.0843       0.0689       0.1183
# 2         0.0262       0.0582       0.1099       0.1083       0.0974
# 3         0.0100       0.0171       0.0623       0.0205       0.0205
# 4         0.0762       0.0666       0.0481       0.0394       0.0590
# ..           ...          ...          ...          ...          ...
# 203       0.0187       0.0346       0.0168       0.0177       0.0393
# 204       0.0323       0.0101       0.0298       0.0564       0.0760
# 205       0.0522       0.0437       0.0180       0.0292       0.0351
# 206       0.0303       0.0353       0.0490       0.0608       0.0167
# 207       0.0260       0.0363       0.0136       0.0272       0.0214
#
#      attribute_6  attribute_7  attribute_8  attribute_9  attribute_10  ...  \
# ...

# %%
sonar['attribute_1']
# Out:
# 0      0.0200
# 1      0.0453
# 2      0.0262
# 3      0.0100
# 4      0.0762
#         ...
# 203    0.0187
# 204    0.0323
# 205    0.0522
# 206    0.0303
# 207    0.0260
# Name: attribute_1, Length: 208, dtype: float64

# %%
sonar[-5:]
# Out:
#      attribute_1  attribute_2  attribute_3  attribute_4  attribute_5  \
# 203       0.0187       0.0346       0.0168       0.0177       0.0393
# 204       0.0323       0.0101       0.0298       0.0564       0.0760
# 205       0.0522       0.0437       0.0180       0.0292       0.0351
# 206       0.0303       0.0353       0.0490       0.0608       0.0167
# 207       0.0260       0.0363       0.0136       0.0272       0.0214
#
#      attribute_6  attribute_7  attribute_8  attribute_9  attribute_10  ...  \
# 203       0.1630       0.2028       0.1694       0.2328        0.2684  ...
# 204       0.0958       0.0990       0.1018       0.1030        0.2154  ...
# 205       0.1171       0.1257       0.1178       0.1258        0.2529  ...
# 206       0.1354       0.1465       0.1123       0.1945        0.2354  ...
# 207       0.0338       0.0655       0.1400       0.1843        0.2354  ...
#
#      attribute_52  attribute_53  attribute_54  attribute_55  attribute_56  \
# ...

# %%
x=sonar['attribute_1']
y=sonar['attribute_2']

# %%
from matplotlib import pyplot as plt
plt.plot(x,y)
plt.show()

# %%
x_train=np.array(sonar.iloc[1:,:-1])
y_train=np.array(sonar.iloc[:,-1])

# %%
x_train
# Out:
# array([[0.0453, 0.0523, 0.0843, ..., 0.0049, 0.0052, 0.0044],
#        [0.0262, 0.0582, 0.1099, ..., 0.0164, 0.0095, 0.0078],
#        [0.01  , 0.0171, 0.0623, ..., 0.0044, 0.004 , 0.0117],
#        ...,
#        [0.0522, 0.0437, 0.018 , ..., 0.0138, 0.0077, 0.0031],
#        [0.0303, 0.0353, 0.049 , ..., 0.0079, 0.0036, 0.0048],
#        [0.026 , 0.0363, 0.0136, ..., 0.0036, 0.0061, 0.0115]])

# %%
y_train[:104]
# Out:
# array(['Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock',
#        'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock',
#        'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock',
#        'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock',
#        'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock',
#        'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock',
#        'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock',
#        'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock',
#        'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock',
#        'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock',
#        'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock',
#        'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock',
#        'Rock', 'Mine', 'Mine', 'Mine', 'Mine', 'Mine', 'Mine', 'Mine'],
#       dtype=object)
